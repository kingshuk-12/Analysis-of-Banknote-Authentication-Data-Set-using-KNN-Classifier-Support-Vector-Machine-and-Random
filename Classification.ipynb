# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Dataset

# %%
dataset = pd.read_csv("dataset.csv")
dataset.head()
# Out:
#     Input1  Input2  Input3   Input4  Output
# 0  3.62160  8.6661 -2.8073 -0.44699       0
# 1  4.54590  8.1674 -2.4586 -1.46210       0
# 2  3.86600 -2.6383  1.9242  0.10645       0
# 3  3.45660  9.5228 -4.0112 -3.59440       0
# 4  0.32924 -4.4552  4.5718 -0.98880       0

# %%
# Feature and Label
features = dataset.iloc[:, 0:4]
label = dataset.iloc[:, 4]

# %%
plt.plot(dataset)
plt.legend(["Input1","Input2","Input3","Input4"])
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
plt.matshow(dataset.corr())

# %% [markdown]
# # K Nearest Neighbour

# %% [markdown]
# ## Generate Model

# %%
X_train, X_test, y_train, y_test = train_test_split(features, label, random_state=42,test_size=0.3) # 70% Train, 30% Test


from sklearn.neighbors import KNeighborsClassifier


knn = KNeighborsClassifier(n_neighbors=100)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %% [markdown]
# ## Accuracy

# %%
print("Train Accuracy:",metrics.accuracy_score(y_train, clf.predict(X_train)))
print("Test Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.9757281553398058

# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# ## Generating Model

# %%
from sklearn import svm

clf = svm.SVC(kernel='linear') 

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

# %% [markdown]
# ## Accuracy

# %%
print("Train Accuracy:",metrics.accuracy_score(y_train, clf.predict(X_train)))
print("Test Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Train Accuracy: 0.9885416666666667
# Test Accuracy: 0.9878640776699029

# %% [markdown]
# ### Using RBF Kernel

# %% [markdown]
# ## Generating Model

# %%
from sklearn import svm

clf = svm.SVC(kernel='rbf') 

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

# %% [markdown]
# ## Accuracy

# %%
print("Train Accuracy:",metrics.accuracy_score(y_train, clf.predict(X_train)))
print("Test Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Train Accuracy: 0.9947916666666666
# Test Accuracy: 1.0

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Generating Model

# %%
from sklearn.ensemble import RandomForestClassifier

clf=RandomForestClassifier(n_estimators=100)


clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %%
print("Train Accuracy:",metrics.accuracy_score(y_train, clf.predict(X_train)))
print("Test Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.9951456310679612
